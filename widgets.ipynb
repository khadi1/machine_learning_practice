# %% [markdown]
# <a href="https://colab.research.google.com/github/khadi1/machine_learning_practice/blob/main/widgets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %%writefile text.txt
#
# hello world
# Out:
# Writing text.txt

# %%
with open ('text.txt' , 'r') as f:
  print(f.read())
# Out:
# hello world

# %%
from IPython.core.magic import (register_line_magic,
                                register_cell_magic)

# %%
import pandas as pd
from io import StringIO

@register_cell_magic
def csv(line, cell):
    # We create a string buffer containing the
    # contents of the cell.
    sio = StringIO(cell)
    # We use Pandas' read_csv function to parse
    # the CSV string.
    return pd.read_csv(sio)

# %%
# %%csv
# col1,col2,col3
# 0,1,2
# 3,4,5
# 7,8,9
# Out:
#    col1  col2  col3
# 0     0     1     2
# 1     3     4     5
# 2     7     8     9

# %%
d=_

# %%
d
# Out:
#    col1  col2  col3
# 0     0     1     2
# 1     3     4     5
# 2     7     8     9

# %%
l= [1,2,3,
     4,5,6]

# %%
print(*l , sep= ' + ' ,end =' = %d' %sum(l))
# Out:
# 1 + 2 + 3 + 4 + 5 + 6 = 21

# %%
f1 , *rest  ,last  = l
print(f1)
# Out:
# 1

# %%
print(*rest)
# Out:
# 2 3 4 5

# %%
def kinetic_energy(mass: 'kg',
                   velocity: 'm/s') -> 'J':
    """The annotations serve here as documentation."""

# %%
annotations = kinetic_energy.__annotations__
annotations.items()
# Out:
# dict_items([('mass', 'kg'), ('velocity', 'm/s'), ('return', 'J')])

# %%
# %%writefile first.py
def first(l):
    return l[0]
# Out:
# Writing first.py

# %%
# %%writefile  first.py -a
#
# # This is appended to the file.
# def test_first():
#     assert first([1, 2, 3]) == 1
# Out:
# Appending to first.py

# %%
# %cat first.py
# Out:
# def first(l):
#     return l[0]
#
# # This is appended to the file.
# def test_first():
#     assert first([1, 2, 3]) == 1

# %%
# !pytest first.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-3.6.4, py-1.11.0, pluggy-0.7.1
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 1 item
#
# first.py .                                                               [100%]
#
# =========================== 1 passed in 0.02 seconds ===========================

# %%
# %%writefile first.py
def first(l):
    return l[0]

def test_first():
    assert first([1, 2, 3]) == 1
    assert first([]) is None
# Out:
# Overwriting first.py

# %%
# !pytest first.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-3.6.4, py-1.11.0, pluggy-0.7.1
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 1 item
#
# first.py F                                                               [100%]
#
# =================================== FAILURES ===================================
# __________________________________ test_first __________________________________
#
#     def test_first():
#         assert first([1, 2, 3]) == 1
# >       assert first([]) is None
#
# first.py:6:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# l = []
#
#     def first(l):
# >       return l[0]
# E       IndexError: list index out of range
#
# first.py:2: IndexError
# =========================== 1 failed in 0.04 seconds ===========================

# %%
# %%writefile first.py
def first(l):
    return l[0] if l else None

def test_first():
    assert first([1, 2, 3]) == 1
    assert first([]) is None
# Out:
# Overwriting first.py

# %%
# !pytest first.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-3.6.4, py-1.11.0, pluggy-0.7.1
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 1 item
#
# first.py .                                                               [100%]
#
# =========================== 1 passed in 0.02 seconds ===========================

# %%
# !pip install ipythonblocks
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.7 MB/s eta 0:00:00
# ...

# %%
import time 
from IPython.display import clear_output 
from ipythonblocks import BlockGrid , colors

# %%
grid= BlockGrid(width = 5  , height = 5  , fill= colors['Purple'])
grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks194a4b77-f58b-4427-8a67-0e97c987b46e td {border: 1px solid white;}</style><table id="blocks194a4b77-f58b-4427-8a67-0e97c987b46e" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;background-color: rgb(128, 0, 128);"></td><td title="Index: [0, 1]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;background-color: rgb(128, 0, 128);"></td><td title="Index: [0, 2]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;background-color: rgb(128, 0, 128);"></td><td title="Index: [0, 3]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;background-color: rgb(128, 0, 128);"></td><td title="Index: [0, 4]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;background-color: rgb(128, 0, 128);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (128, 0, 128)" style="width: 20px; height: 
# ...

# %%
grid[0 ,0] = colors['Lime']
grid[-1, 0] = colors['Lime']
grid[:, -1] = colors['Lime']

grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksea414e6f-713f-4d21-afea-c3df57efd791 td {border: 1px solid white;}</style><table id="blocksea414e6f-713f-4d21-afea-c3df57efd791" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 0);"></td><td title="Index: [0, 1]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;background-color: rgb(128, 0, 128);"></td><td title="Index: [0, 2]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;background-color: rgb(128, 0, 128);"></td><td title="Index: [0, 3]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;background-color: rgb(128, 0, 128);"></td><td title="Index: [0, 4]&#10;Color: (0, 255, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (128, 0, 128)" style="width: 20px; height: 20px;bac
# ...

# %%
import matplotlib.pyplot as plt
img = plt.imread('https://github.com/ipython-books/'
                 'cookbook-2nd-data/blob/master/'
                 'beach.png?raw=true')[::4, ::4, :]
plt.imshow(img)

# %%
rgb = [img[..., i].ravel() for i in range(3)]
rgb
# Out:
# [array([0.8666667 , 0.8666667 , 0.8509804 , ..., 0.47843137, 0.77254903,
#         0.41568628], dtype=float32),
#  array([0.9019608 , 0.9019608 , 0.89411765, ..., 0.3529412 , 0.64705884,
#         0.2901961 ], dtype=float32),
#  array([0.92941177, 0.92941177, 0.91764706, ..., 0.25490198, 0.5568628 ,
#         0.2       ], dtype=float32)]

# %%
height , width = img.shape[:2]
grid = BlockGrid(width=width, height=height,
                 block_size=2, lines_on=False)

for block , r, g, b in zip (grid , *rgb):
  block.rgb = (r*255 , g *255 ,b*255)


grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb0dfac1a-32e7-48a4-bb98-6f3135258878 td {border: 0px solid white;}</style><table id="blocksb0dfac1a-32e7-48a4-bb98-6f3135258878" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (221, 230, 237)" style="width: 2px; height: 2px;background-color: rgb(221, 230, 237);"></td><td title="Index: [0, 1]&#10;Color: (221, 230, 237)" style="width: 2px; height: 2px;background-color: rgb(221, 230, 237);"></td><td title="Index: [0, 2]&#10;Color: (217, 228, 234)" style="width: 2px; height: 2px;background-color: rgb(217, 228, 234);"></td><td title="Index: [0, 3]&#10;Color: (219, 230, 236)" style="width: 2px; height: 2px;background-color: rgb(219, 230, 236);"></td><td title="Index: [0, 4]&#10;Color: (219, 229, 238)" style="width: 2px; height: 2px;background-color: rgb(219, 229, 238);"></td><td title="Index: [0, 5]&#10;Color: (218, 228, 237)" style="width: 2px; height
# ...

# %%
# !pip  install pandoc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 KB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 5.8 MB/s eta 0:00:00
# ...
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33284 sha256=fbd71370f004396cf7de5fe8936c90eac97edde865e39fc9c6a3b4a18b4b9743
#   Stored in directory: /root/.cache/pip/wheels/90/3a/a8/3237a93e3a6261bd24edabf3277ca59f64c1710b3d8c7c72a0
# Successfully built pandoc
# ...

# %%
import io
import requests

# %%
url ='https://github.com/ipython-books/cookbook-2nd-data/blob/master/test.ipynb?raw=true'

# %%
content = requests.get(url).text
print(len(content))
# Out:
# 3857

# %%
print(content[:345], ... , content[-33:])
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# First chapter"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {
#     "my_field": [
#      "value1",
#      "2405"
#     ]
#    },
#    "source": [
#     "Let's write some *rich* **text** with [links](http://www.ipython.org) and lists:\n",
#     "\n",
#     "* item1 Ellipsis rmat": 4,
#  "nbformat_minor": 4
# }

# %%
import json
nb = json.loads(content)
print('nbformat %d.%d'   % (nb['nbformat'] , nb['nbformat_minor']))
# Out:
# nbformat 4.4

# %%
nb['cells']
# Out:
# {'cell_type': 'code',
#  'execution_count': 1,
#  'metadata': {},
# ...

# %%
nb['cells'][2]['outputs'][0]['data']
# Out:
# {'image/png': '\ncHjvInjzQynxQynxQynxQynxQynxQynxQynxQynxQynxQyn
# ...

# %%
with open('test.ipynb', 'w') as f:
    f.write(content)

# %%
# !jupyter nbconvert --to html test.ipynb
# Out:
# [NbConvertApp] Converting notebook test.ipynb to html
# [NbConvertApp] Writing 276369 bytes to test.html

# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline

# %%
@widgets.interact(x = (0 ,5))
def f(x=5):
  print(x)
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=5), Output()), _dom_classes=('widget-interact',)…

# %%
@widgets.interact_manual(
    color = ['blue' , 'red'  ,'green'] ,lw=(1. , 10.))
def  plot(freq=1., color='blue', lw=2, grid=True):
    t = np.linspace(-1., +1., 1000)
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.plot(t, np.sin(2 * np.pi * freq * t),
            lw=lw, color=color)
    ax.grid(grid)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='freq', max=3.0, min=-1.0), Dropdown(description='col…

# %%
freq_slider = widgets.FloatSlider(
    value=2.,
    min=1.,
    max=10.0,
    step=0.1,
    description='Frequency:',
    readout_format='.1f',
)
freq_slider
# Out:
# FloatSlider(value=2.0, description='Frequency:', max=10.0, min=1.0, readout_format='.1f')

# %%
grid_button = widgets.ToggleButton(
    value=False,
    description='Grid',
    icon='check'
)
grid_button
# Out:
# ToggleButton(value=False, description='Grid', icon='check')

# %%
color_buttons = widgets.ToggleButtons(
    options=['blue', 'red', 'green'],
    description='Color:',
)
color_buttons
# Out:
# ToggleButtons(description='Color:', options=('blue', 'red', 'green'), value='blue')

# %%
title_textbox = widgets.Text(
    value='Hello World',
    description='Title:',
)
title_textbox
# Out:
# Text(value='Hello World', description='Title:')

# %%
color_picker = widgets.ColorPicker(
    concise=True,
    description='Background color:',
    value='#efefef',
)
color_picker
# Out:
# ColorPicker(value='#efefef', concise=True, description='Background color:')

# %%
button = widgets.Button(
    description='Plot',
)
button
# Out:
# Button(description='Plot', style=ButtonStyle())
